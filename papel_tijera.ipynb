# %% [markdown]
# <a href="https://colab.research.google.com/github/GALINDO1/PROGCOM-B/blob/main/papel_tijera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
while True:
  aleatorio = random.randrange(0, 7)
  elijePc = ""
  print("1)Piedra")
  print("2)Papel")
  print("3)Tijera")
  print("4)Spock")
  print("5)Lagarto")
  print("6)Heavy")
  print("7)Papa")
  

  opcion = int(input("Que elijes: "))

  if opcion == 1:
    elijeUsuario = "piedra"
  elif opcion == 2:
    elijeUsuario = "papel"
  elif opcion == 3:
    elijeUsuario = "tijera"
  elif opcion == 4:
    elijeUsuario = "spock"
  elif opcion == 5:
    elijeUsuario = "lagarto"
  elif opcion == 6:
    elijeUsuario = "heavy"
  elif opcion == 7:
    elijeUsuario = "papa"
  print("Tu elijes: ", elijeUsuario)
  

  if aleatorio == 0:
    elijePc = "piedra"
  elif aleatorio == 1:
    elijePc = "papel"
  elif aleatorio == 2:
    elijePc = "tijera"
  elif aleatorio == 3:
    elijePc = "spock"
  elif aleatorio == 4:
    elijePc = "lagarto"
  elif aleatorio == 5:
    elijePc = "papa"
  elif aleatorio == 6:
    elijePc = "heavy"
  print("PC elijio: ", elijePc)
  print("...")

  if elijePc == "piedra" and elijeUsuario == "papel":
    print("Ganaste, papel envulve piedra")
  elif elijePc == "papel" and elijeUsuario == "tijera":
    print("Ganaste, Tijera corta papel")
  elif elijePc == "tijera" and elijeUsuario == "piedra":
    print("Ganaste, Piedra pisa tijera")

  if elijePc== "spock" and elijeUsuario == "lagarto":
    print("Ganaste")
  elif elijePc== "lagarto" and elijeUsuario == "piedra":
    print("Ganaste")
  elif elijePc== "papel" and elijeUsuario == "lagarto":
    print("Ganaste")
  elif elijePc== "lagarto" and elijeUsuario == "tijera":
    print("Ganaste")
  elif elijePc== "piedra" and elijeUsuario == "spock":
    print("Ganaste")
  elif elijePc== "tijera" and elijeUsuario == "spock":
    print("Ganaste")
  elif elijePc== "spock" and elijeUsuario == "papel":
    print("Ganaste")
  

  elif elijePc== "papa" and elijeUsuario == "spock":
    print("Ganaste")
  elif elijePc== "papa" and elijeUsuario == "heavy":
    print("Ganaste")
  elif elijePc== "papel" and elijeUsuario == "papa":
    print("Ganaste")
  elif elijePc== "piedra" and elijeUsuario == "papa":
    print("Ganaste")
  elif elijePc== "heavy" and elijeUsuario == "tijera":
    print("Ganaste")
  elif elijePc== "heavy" and elijeUsuario == "tijera":
    print("Ganaste")
  elif elijePc== "lagarto" and elijeUsuario == "heavy":
    print("Ganaste")
  elif elijePc== "heavy" and elijeUsuario == "piedra":
    print("Ganaste")
  elif elijePc==  "papa" and elijeUsuario == "lagarto":
    print("Ganaste")
  elif elijePc==  "tijeras" and elijeUsuario == "papa":
    print("Ganaste")
  elif elijePc==  "heavy" and elijeUsuario == "papel":
    print("Ganaste")
  elif elijePc==  "spock" and elijeUsuario == "heavy":
    print("Ganaste")


  if elijeUsuario == "piedra" and elijePc == "papel":
     print("perdiste, papel envulve piedra")
  elif elijeUsuario == "papel" and elijePc == "tijera":
     print("perdiste, Tijera corta papel")
  elif elijeUsuario == "tijera" and elijePc == "piedra":
     print("perdiste, Piedra pisa tijera")
  if elijeUsuario ==  "spock" and  elijePc==  "lagarto":
     print("Perdiste")
  elif elijeUsuario ==  "lagarto" and  elijePc== "piedra":
      print("Perdiste")
  elif elijeUsuario == "papel"   and  elijePc== "lagarto":
     print("Perdiste")
  elif elijeUsuario == "lagarto" and  elijePc== "tijera":
     print("Perdiste")
  elif elijeUsuario == "piedra" and  elijePc== "spock":
      print("Perdiste")
  elif elijeUsuario ==  "tijera" and  elijePc== "spock":
     print("Perdiste")
  elif  elijeUsuario == "spock" and  elijePc== "papel" :
     print("Perdiste")

  if elijePc== "spock" and elijeUsuario == "papa":
    print("Perdiste")
  elif elijePc== "heavy" and elijeUsuario == "papa":
    print("Perdiste")
  elif elijePc== "papa"  and elijeUsuario == "papel":
    print("Perdiste")
  elif elijePc==  "papa" and elijeUsuario == "piedra":
    print("Perdiste")
  elif elijePc==  "tijera" and elijeUsuario == "heavy":
    print("Perdiste")
  elif elijePc==  "tijera" and elijeUsuario == "heavy":
    print("Perdiste")
  elif elijePc==  "heavy"and elijeUsuario == "lagarto":
    print("Perdiste")
  elif elijePc== "heavy" and elijeUsuario == "piedra":
    print("Perdiste")
  elif elijePc==  "lagarto" and elijeUsuario == "papa":
    print("Perdiste")
  elif elijePc== "lagarto"  and elijeUsuario == "papa":
    print("Perdiste")
  elif elijePc== "papa"  and elijeUsuario == "tijeras":
    print("Perdiste")
  elif elijePc==  "papel"and elijeUsuario == "heavy" :
    print("Perdiste")
  elif elijePc==  "heavy" and elijeUsuario == "spock":
    print("perdiste")


  if elijeUsuario== elijePc:
    print("Empate")
  elijeUsuario=input("Quieres jugar denuevo(s/n)")
  if  elijeUsuario!="s":
      break
